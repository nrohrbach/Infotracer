# %% [markdown]
# <a href="https://colab.research.google.com/github/nrohrbach/Infotracer/blob/main/Infotracer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Infotracer Test
# s

# %%
import folium
from folium.plugins import Draw
from folium.plugins import Geocoder
from folium.utilities import JsCode
import requests
import json
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
# Create a map centered on Switzerland
map = folium.Map(location=[46.8182, 8.2275],
                 zoom_start=8,
                 height="600px",
                 width="1000px",
                 control_scale=True,
                 tiles="https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.pixelkarte-farbe/default/current/3857/{z}/{x}/{y}.jpeg",
                 attr='Map data: &copy; <a href="https://www.swisstopo.ch" target="_blank" rel="noopener noreferrer">swisstopo</a>'
                 )

# Feature Group wo eingzeichnete Geometrien gespeichert werden
folium.FeatureGroup(name="Geometrien").add_to(map)

# JavaScript code to store coordinates in variables
js_code = """
function(e) {
    var lat = e.latlng.lat;
    var lng = e.latlng.lng;

    // Store the coordinates in JavaScript variables
    var myLat = lat;
    var myLng = lng;

    // Log the coordinates to the console for verification
    console.log("Latitude:", myLat);
    console.log("Longitude:", myLng);

    // Optionally, you can send the coordinates to Python using a custom function
    // Example:  google.colab.kernel.invokeFunction('store_coordinates', [myLat, myLng], {});
}
"""

# Zeichenfunktion einführen.
Draw(
    export=False,
    show_geometry_on_click=True,
    position='topleft',
    draw_options={
        'polyline': False,
        'polygon': False,
        'circle': False,
        'circlemarker': False,
        'marker': True,
        'rectangle': False,
    },
    edit_options={'edit': False,
                  'remove':False},
    on={
        "draw:created": JsCode(js_code) # Use draw:created event
    },
).add_to(map)

Geocoder(
    add_marker=False,
    zoom=15
).add_to(map)


map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acd1dbecb69661220948b8a178c069ad {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acd1dbecb69661220948b8a178c069ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acd1dbecb69661220948b8a178c069ad = L.map(
#                 &quot;map_acd1dbecb69661220948b8a178c069ad&quot;,
#                 {
#                     center: [46.8182, 8.2275],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_acd1dbecb69661220948b8a178c069ad);
#
#
#
#
#
#             var tile_layer_e33993cf255be0c7a0d660c716232a48 = L.tileLayer(
#                 &quot;https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.pixelkarte-farbe/default/current/3857/{z}/{x}/{y}.jpeg&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map data: \u0026copy; \u003ca href=\&quot;https://www.swisstopo.ch\&quot; target=\&quot;_blank\&quot; rel=\&quot;noopener noreferrer\&quot;\u003eswisstopo\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e33993cf255be0c7a0d660c716232a48.addTo(map_acd1dbecb69661220948b8a178c069ad);
#
#
#             var feature_group_108b5519f5c3fadc35081b496319e6bc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_108b5519f5c3fadc35081b496319e6bc.addTo(map_acd1dbecb69661220948b8a178c069ad);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {&quot;circle&quot;: false, &quot;circlemarker&quot;: false, &quot;marker&quot;: true, &quot;polygon&quot;: false, &quot;polyline&quot;: false, &quot;rectangle&quot;: false},
#               edit: {&quot;edit&quot;: false, &quot;remove&quot;: false},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_2e8dd97ceefd87bd3b16896c09612fc0 =
#                     new L.featureGroup().addTo(
#                         map_acd1dbecb69661220948b8a178c069ad
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_2e8dd97ceefd87bd3b16896c09612fc0;
#             var draw_control_2e8dd97ceefd87bd3b16896c09612fc0 = new L.Control.Draw(
#                 options
#             ).addTo( map_acd1dbecb69661220948b8a178c069ad );
#             map_acd1dbecb69661220948b8a178c069ad.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 layer.on(
#                     &quot;draw:created&quot;,
#
# function(e) {
#     var lat = e.latlng.lat;
#     var lng = e.latlng.lng;
#
#     // Store the coordinates in JavaScript variables
#     var myLat = lat;
#     var myLng = lng;
#
#     // Log the coordinates to the console for verification
#     console.log(&quot;Latitude:&quot;, myLat);
#     console.log(&quot;Longitude:&quot;, myLng);
#
#     // Optionally, you can send the coordinates to Python using a custom function
#     // Example:  google.colab.kernel.invokeFunction(&#x27;store_coordinates&#x27;, [myLat, myLng], {});
# }
#
#                 );
#                 drawnItems_draw_control_2e8dd97ceefd87bd3b16896c09612fc0.addLayer(layer);
#             });
#             map_acd1dbecb69661220948b8a178c069ad.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_2e8dd97ceefd87bd3b16896c09612fc0.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_a4c65e7c1a48a7903846af83e5b7faed = {
#   &quot;collapsed&quot;: false,
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;defaultMarkGeocode&quot;: false,
#   &quot;zoom&quot;: 15,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_a4c65e7c1a48a7903846af83e5b7faed = geocoderOpts_geocoder_a4c65e7c1a48a7903846af83e5b7faed[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_a4c65e7c1a48a7903846af83e5b7faed = L.Control.Geocoder[ geocoderName_geocoder_a4c65e7c1a48a7903846af83e5b7faed ](
#                 geocoderOpts_geocoder_a4c65e7c1a48a7903846af83e5b7faed[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_a4c65e7c1a48a7903846af83e5b7faed[&quot;geocoder&quot;] = customGeocoder_geocoder_a4c65e7c1a48a7903846af83e5b7faed;

# %% [markdown]
# ## Todo
# Koordinaten abfangen und weiterverwenden

# %%
# Temporär Koordinaten und Radius eingeben
#####################
coordinates= [9.843278,46.497595]
Radius = 5000
#####################

easting = coordinates[0]
northing = coordinates[1]

# %% [markdown]
# ## Transformation der Koordinaten von WGS84 in LV95
# Die swisstopo API mit Distanzangabe läuft am Besten in LV95. Grund ist dass LV95 bereits in Meter ist. WGS84 in Grad.

# %%
def get_lv95_coordinates(easting, northing):
    url = f"https://geodesy.geo.admin.ch/reframe/wgs84tolv95?easting={easting}&northing={northing}&format=json"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes (4xx or 5xx)
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

lv95_data = get_lv95_coordinates(easting, northing)

if lv95_data:
    #print(json.dumps(lv95_data, indent=2)) #Nicely formatted JSON output
    # Access specific coordinate values
     easting_lv95 = float(lv95_data["easting"])
     northing_lv95 = float(lv95_data["northing"])

# %% [markdown]
# # Abfrage des APIs

# %%
#Bounding Box für Radius Abfrage erstellen
mapExtent = [0,0,0,0]
mapExtent[0] = easting_lv95-Radius
mapExtent[1] = northing_lv95-Radius
mapExtent[2] = easting_lv95+Radius
mapExtent[3] = northing_lv95+Radius

# %%
def query_geo_admin_api(coordinates):
    """Queries the Swiss Geo Admin API for information at given coordinates."""

    url = "https://api3.geo.admin.ch/rest/services/all/MapServer/identify"
    params = {
        "geometry":  f"{mapExtent[0]},{mapExtent[1]},{ mapExtent[2]},{mapExtent[3]}",  # Longitude, Latitude
        "geometryFormat": "geojson",
        "geometryType": "esriGeometryEnvelope",
        "sr": "2056",
        "lang": "de",
        "layers": "all:ch.bafu.hydrogeologie-markierversuche",
        "returnGeometry": "true",
        "tolerance": 0
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise an exception for bad status codes

        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error querying Geo Admin API: {e}")
        return None

api_response = query_geo_admin_api(coordinates)

# %% [markdown]
# # Antworten der API als Dataframe speichern und auf Karte darstellen

# %%
# Antworten des API als Dataframe speichern
if api_response:
    results = []
    for feature in api_response['results']:
        result = {
            'x': feature["properties"]['x'],
            'y': feature["properties"]['y'],
            'ort': feature["properties"]['ort'],
            'datum': feature["properties"]['datum'],
            'milieu': feature["properties"]['milieu'],
            'marker': feature["properties"]['markierstoff'],
            'menge': feature["properties"]['menge_einheit'],
            'label' : feature["properties"]['label']
        }
        results.append(result)
    else:
        print("No results found.")
# Create a Pandas DataFrame
df = pd.DataFrame(results)

# Create a Geodataframe
dfgeo = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.x, df.y),crs='EPSG:2056')

# Startpunkt als Geodataframe speichern als Grundlage für Distanzberechnung
startpunkt = Point(easting_lv95, northing_lv95)
startpunkt_geoseries = gpd.GeoSeries([startpunkt], crs=dfgeo.crs)

#Distanz von Resultaten zu Startpunkt berechnen
dfgeo['Distanz'] = round(dfgeo.distance(startpunkt_geoseries[0]),0)

# Convert the GeoDataFrame's CRS to WGS84 (latitude/longitude) for Folium
dfgeo = dfgeo.to_crs(epsg=4326)

# Create a map centered on Switzerland
mapresults = folium.Map(location=[northing,easting],
                 zoom_start=14,
                 height="600px",
                 width="1000px",
                 control_scale=True,
                 tiles="https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.pixelkarte-farbe/default/current/3857/{z}/{x}/{y}.jpeg",
                 attr='Map data: &copy; <a href="https://www.swisstopo.ch" target="_blank" rel="noopener noreferrer">swisstopo</a>'
                 )
if api_response:
    # Add markers to the map
  for index, row in dfgeo.iterrows():
      folium.Marker(
          location=[row.geometry.y, row.geometry.x],  # Latitude, Longitude
          popup=f"Ort: {row['ort']}<br>Datum: {row['datum']}<br>Milieu: {row['milieu']}<br>Marker: {row['marker']}<br>Menge: {row['menge']},<br>Distanz (m): {row['Distanz']}",
          tooltip=row['label'],
      ).add_to(mapresults)



# Add Startpunkt to the map
folium.Marker(
    location=  [northing,easting],  # Latitude, Longitude
    popup=f"Startpunkt",
    tooltip=f"Startpunkt",
    icon=folium.Icon(color='green')
).add_to(mapresults)


mapresults
# Out:
# No results found.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fc70bde21f254313adb7601fd255df2 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fc70bde21f254313adb7601fd255df2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fc70bde21f254313adb7601fd255df2 = L.map(
#                 &quot;map_8fc70bde21f254313adb7601fd255df2&quot;,
#                 {
#                     center: [46.497595, 9.843278],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_8fc70bde21f254313adb7601fd255df2);
#
#
#
#
#
#             var tile_layer_5aac42f416d83926678c9ed5cf3a8b6d = L.tileLayer(
#                 &quot;https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.pixelkarte-farbe/default/current/3857/{z}/{x}/{y}.jpeg&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map data: \u0026copy; \u003ca href=\&quot;https://www.swisstopo.ch\&quot; target=\&quot;_blank\&quot; rel=\&quot;noopener noreferrer\&quot;\u003eswisstopo\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5aac42f416d83926678c9ed5cf3a8b6d.addTo(map_8fc70bde21f254313adb7601fd255df2);
#
#
#             var marker_e3bbecf01ea5b4112a59c42ee8a0991a = L.marker(
#                 [46.54023085577613, 9.894768195637647],
#                 {
# }
#             ).addTo(map_8fc70bde21f254313adb7601fd255df2);
#
#
#         var popup_5443eac97244fb300607bb1fb39aea85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfcd3531e96483072840471179d939dc = $(`&lt;div id=&quot;html_bfcd3531e96483072840471179d939dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ort: Samedan&lt;br&gt;Datum: 21.04.1988&lt;br&gt;Milieu: None&lt;br&gt;Marker: Fluorescein&lt;br&gt;Menge: 0.005 kg,&lt;br&gt;Distanz (m): 6171.0&lt;/div&gt;`)[0];
#                 popup_5443eac97244fb300607bb1fb39aea85.setContent(html_bfcd3531e96483072840471179d939dc);
#
#
#
#         marker_e3bbecf01ea5b4112a59c42ee8a0991a.bindPopup(popup_5443eac97244fb300607bb1fb39aea85)
#         ;
#
#
#
#
#             marker_e3bbecf01ea5b4112a59c42ee8a0991a.bindTooltip(
#                 `&lt;div&gt;
#                      788
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0a6f3405a92c3a7282cf417dcc970a30 = L.marker(
#                 [46.52415592491389, 9.81482854308855],
#                 {
# }
#             ).addTo(map_8fc70bde21f254313adb7601fd255df2);
#
#
#         var popup_81b5f24cf6be924ffdec95f5bb91ed2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbce9d63927e410dd7e0be807fa47e1a = $(`&lt;div id=&quot;html_fbce9d63927e410dd7e0be807fa47e1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ort: Celerina&lt;br&gt;Datum: 01.09.1992&lt;br&gt;Milieu: None&lt;br&gt;Marker: Fluoreszein&lt;br&gt;Menge: 0.2 kg,&lt;br&gt;Distanz (m): 3672.0&lt;/div&gt;`)[0];
#                 popup_81b5f24cf6be924ffdec95f5bb91ed2c.setContent(html_fbce9d63927e410dd7e0be807fa47e1a);
#
#
#
#         marker_0a6f3405a92c3a7282cf417dcc970a30.bindPopup(popup_81b5f24cf6be924ffdec95f5bb91ed2c)
#         ;
#
#
#
#
#             marker_0a6f3405a92c3a7282cf417dcc970a30.bindTooltip(
#                 `&lt;div&gt;
#                      2508
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ead8f5b3ee5a8d02c4d9228c55f14c01 = L.marker(
#                 [46.51673062701914, 9.825583860025693],
#                 {
# }
#             ).addTo(map_8fc70bde21f254313adb7601fd255df2);
#
#
#         var popup_3e8d84a7cec05b4c74f1463e02e9f3d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f57fdaf46551a8203546752996cafea = $(`&lt;div id=&quot;html_2f57fdaf46551a8203546752996cafea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ort: Celerina&lt;br&gt;Datum: 01.09.1992&lt;br&gt;Milieu: None&lt;br&gt;Marker: Amidoflavin&lt;br&gt;Menge: 0.2 kg,&lt;br&gt;Distanz (m): 2524.0&lt;/div&gt;`)[0];
#                 popup_3e8d84a7cec05b4c74f1463e02e9f3d3.setContent(html_2f57fdaf46551a8203546752996cafea);
#
#
#
#         marker_ead8f5b3ee5a8d02c4d9228c55f14c01.bindPopup(popup_3e8d84a7cec05b4c74f1463e02e9f3d3)
#         ;
#
#
#
#
#             marker_ead8f5b3ee5a8d02c4d9228c55f14c01.bindTooltip(
#                 `&lt;div&gt;
#                      2509
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_dfa6f62ce0260b73c7c686356f255043 = L.marker(
#                 [46.525135464887825, 9.83247391939891],
#                 {
# }
#             ).addTo(map_8fc70bde21f254313adb7601fd255df2);
#
#
#         var popup_6fca260b62a49c025a912da5e6587d37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f068fbecc399e310937f130d6c164a0 = $(`&lt;di

# %%
dfgeo
# Out:
#             x          y             ort       datum               milieu  \
# 0   2521145.0  1155950.0          Apples  28.05.1985                 None
# 1   2519360.0  1156040.0         Ballens  10.09.1985                 None
# 2   2519520.0  1156580.0         Ballens  10.09.1985                 None
# 3   2519620.0  1156500.0         Ballens  10.09.1985                 None
# 4   2521145.0  1155950.0          Apples  27.10.1986                 None
# 5   2519600.0  1154600.0            Yens  21.09.1988                 None
# 6   2519850.0  1154650.0            Yens  21.09.1988                 None
# 7   2519850.0  1154800.0            Yens  21.09.1988                 None
# 8   2520775.0  1154500.0            Yens  21.09.1988                 None
# 9   2521080.0  1155580.0          Apples  24.08.1992                 None
# 10  2517390.0  1154670.0           Bière  30.11.1992                 None
# 11  2520800.0  1155280.0          Apples  09.03.1993                 None
# 12  2520900.0  1155720.0          Apples  09.03.1993                 None
# 13  2517570.0  1154480.0           Bière  22.03.1993                 None
# 14  2521100.0  1154425.0  Reverolle (VD)  15.06.2004    Ungesättigte Zone
# 15  2521125.0  1154400.0  Reverolle (VD)  15.06.2004    Ungesättigte Zone
# 16  2519850.0  1155400.0    Ballens (VD)  23.11.2016          Grundwasser
# 17  2520010.0  1155788.0    Ballens (VD)  23.11.2016  Oberflächengewässer
#
#           marker    menge  label                  geometry  Distanz
# 0   Fluorescéine     2 kg    136  POINT (6.41044 46.55017)   2023.0
# 1   Fluorescéine     1 kg    220  POINT (6.38715 46.55077)    341.0
# 2   Fluorescéine     1 kg    221  POINT (6.38914 46.55565)    453.0
# 3          Iodid     5 kg    222  POINT (6.39046 46.55494)    502.0
# 4   Fluorescéine     2 kg    434  POINT (6.41044 46.55017)   2023.0
# 5         Duasyn     1 kg    967  POINT (6.39053 46.53785)   1769.0
# 6          Eosin     1 kg    968  POINT (6.39378 46.53833)   1802.0
# 7   Fluorescéine     1 kg    969  POINT (6.39375 46.53968)   1664.0
# 8           NaCl  1000 kg    971  POINT (6.40586 46.53709)   2431.0
# 9         Duasyn   1.5 kg   2504  POINT (6.40965 46.54684)   2060.0
# 10        Duasyn   1.5 kg   2652  POINT (6.36171 46.53821)   2411.0
# 11         Eosin     4 kg   2684  POINT (6.40606 46.54411)   1942.0
# 12  Fluorescéine     4 kg   2685  POINT (6.40728 46.54808)   1843.0
# 13  Fluorescéine     2 kg   2687  POINT (6.36409 46.53652)   2423.0
# 14         Eosin   0.5 kg   5710  POINT (6.41011 46.53645)   2710.0
# 15       Lithium     3 kg   5711  POINT (6.41044 46.53623)   2745.0
# 16         Eosin     1 kg   9165  POINT (6.39365 46.54507)   1147.0
# 17        Uranin     2 kg   9166  POINT (6.39567 46.54858)   1003.0
